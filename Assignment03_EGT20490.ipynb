# %%
! pip install supervision
! pip install ultralytics
# Out:
# Collecting supervision
#   Using cached supervision-0.25.1-py3-none-any.whl.metadata (14 kB)
# Collecting contourpy>=1.0.7 (from supervision)
#   Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from supervision) (0.7.1)
# Collecting matplotlib>=3.6.0 (from supervision)
#   Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.21.2 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from supervision) (2.2.2)
# Collecting opencv-python>=4.5.5.64 (from supervision)
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=9.4 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from supervision) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from supervision) (6.0.2)
# Requirement already satisfied: requests>=2.26.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from supervision) (2.32.3)
# Collecting scipy<2.0.0,>=1.10.0 (from supervision)
#   Using cached scipy-1.15.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: tqdm>=4.62.3 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from supervision) (4.67.1)
# Collecting cycler>=0.10 (from matplotlib>=3.6.0->supervision)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: fonttools>=4.22.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from matplotlib>=3.6.0->supervision) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from matplotlib>=3.6.0->supervision) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from matplotlib>=3.6.0->supervision) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from matplotlib>=3.6.0->supervision) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from matplotlib>=3.6.0->supervision) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests>=2.26.0->supervision) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests>=2.26.0->supervision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests>=2.26.0->supervision) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests>=2.26.0->supervision) (2025.1.31)
# Requirement already satisfied: colorama in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from tqdm>=4.62.3->supervision) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.17.0)
# Using cached supervision-0.25.1-py3-none-any.whl (181 kB)
# Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# Using cached scipy-1.15.1-cp312-cp312-win_amd64.whl (43.6 MB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Installing collected packages: scipy, opencv-python, cycler, contourpy, matplotlib, supervision
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'D:\\8th SEM\\Machine Vision\\Assignment\\Assignment_03\\YOLO11\\myenv\\Lib\\site-packages\\scipy\\sparse\\_sparsetools.cp312-win_amd64.pyd'
# Check the permissions.
# Collecting ultralytics
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'D:\\8th SEM\\Machine Vision\\Assignment\\Assignment_03\\YOLO11\\myenv\\Lib\\site-packages\\sympy\\core\\alphabets.py'
# Check the permissions.
#   Using cached ultralytics-8.3.73-py3-none-any.whl.metadata (35 kB)
# Collecting numpy<=2.1.1,>=1.23.0 (from ultralytics)
#   Using cached numpy-2.1.1-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Collecting matplotlib>=3.3.0 (from ultralytics)
#   Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from ultralytics) (2.32.3)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Using cached scipy-1.15.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting torch>=1.8.0 (from ultralytics)
#   Using cached torch-2.6.0-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.21.0-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm>=4.64.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from ultralytics) (6.1.1)
# Requirement already satisfied: py-cpuinfo in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from ultralytics) (9.0.0)
# Collecting pandas>=1.1.4 (from ultralytics)
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.0->ultralytics)
#   Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: cycler>=0.10 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Using cached filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Collecting networkx (from torch>=1.8.0->ultralytics)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Collecting fsspec (from torch>=1.8.0->ultralytics)
#   Using cached fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (75.8.0)
# Collecting sympy==1.13.1 (from torch>=1.8.0->ultralytics)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Using cached ultralytics-8.3.73-py3-none-any.whl (914 kB)
# Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached numpy-2.1.1-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached scipy-1.15.1-cp312-cp312-win_amd64.whl (43.6 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached torch-2.6.0-cp312-cp312-win_amd64.whl (204.1 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached torchvision-0.21.0-cp312-cp312-win_amd64.whl (1.6 MB)
# Using cached ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Using cached filelock-3.17.0-py3-none-any.whl (16 kB)
# Using cached fsspec-2025.2.0-py3-none-any.whl (184 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Installing collected packages: sympy, numpy, networkx, fsspec, filelock, torch, scipy, pandas, opencv-python, contourpy, ultralytics-thop, torchvision, matplotlib, seaborn, ultralytics

# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image
import time
import supervision as sv
import torch

# %%
img = cv2.imread("demo5_images/cars1.jpg")

# %%
# Load the YOLO segmentation model
model = YOLO("yolo11n-seg.pt")  # Load your model

# Run inference on an image
image_path = "demo5_images/cars1.jpg"  # Replace with your image path
results = model(image_path)  # Perform segmentation

# Initialize variables to track the largest box
largest_area = 0
largest_box_index = -1

# Iterate through the boxes in the results object
for result in results:
    if result.masks:  # Check if masks exist
        for i, (mask, box) in enumerate(zip(result.masks.xy, result.boxes)):
            # Convert mask points to a contour format
            contour = np.array(mask, dtype=np.int32)
            area = cv2.contourArea(contour)  # Compute the area

            # Find out the index of the box with the largest area
            if area > largest_area:
                largest_area = area
                largest_box_index = i  # Store the index of the box with the largest area

# Draw the mask of the box with the largest area
if largest_box_index != -1:
    # Reload the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB for display

    # Get the largest mask
    largest_mask = results[0].masks.xy[largest_box_index]

    # Convert to integer array
    largest_mask = np.array(largest_mask, dtype=np.int32)

    # Draw the mask on the image
    cv2.polylines(image, [largest_mask], isClosed=True, color=(0, 255, 0), thickness=2)
    cv2.fillPoly(image, [largest_mask], color=(0, 255, 0, 100))  # Fill mask with transparency

    # Display the image with the mask
    plt.imshow(image)
    plt.axis("off")
    plt.title("Largest Object Mask")
    plt.show()
else:
    print("No segmentation masks detected!")
# Out:
# image 1/1 d:\8th SEM\Machine Vision\Assignment\Assignment_03\YOLO11\myenv\demo5_images\cars1.jpg: 416x640 14 cars, 843.0ms
# Speed: 2.0ms preprocess, 843.0ms inference, 284.1ms postprocess per image at shape (1, 3, 416, 640)

# %%
# Load YOLO segmentation model
model = YOLO("yolov8n-seg.pt")

# Run inference on an image
image_path = "demo5_images/cars1.jpg"
results = model(image_path)

# Convert results to Supervision format
supervision_detections = sv.Detections.from_ultralytics(results[0])

# Extract masks and class IDs
masks = supervision_detections.mask
class_ids = supervision_detections.class_id

# Load class names (COCO dataset)
class_names = model.names

# Identify the largest car mask
largest_area = 0
largest_mask = None

for mask, class_id in zip(masks, class_ids):
    if class_names[class_id] == "car":  # Filter only cars
        area = np.sum(mask)  # Count pixels in the mask (approximate area)
        if area > largest_area:
            largest_area = area
            largest_mask = mask

# Draw the largest mask on the image
if largest_mask is not None:
    # Load the original image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for matplotlib

    # Convert mask to a format usable by OpenCV
    largest_mask = (largest_mask * 255).astype(np.uint8)  # Convert to binary mask
    contours, _ = cv2.findContours(largest_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Draw the mask
    cv2.drawContours(image, contours, -1, (255, 0, 0), 2)  # Blue outline
    image[largest_mask > 0] = [255, 0, 0]  # Fill mask with color

    # Display the image
    plt.imshow(image)
    plt.axis("off")
    plt.title("Largest Car Mask")
    plt.show()
else:
    print("No car detected!")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n-seg.pt to 'yolov8n-seg.pt'...
# 100%|██████████| 6.74M/6.74M [01:21<00:00, 86.8kB/s]
# image 1/1 d:\8th SEM\Machine Vision\Assignment\Assignment_03\YOLO11\myenv\demo5_images\cars1.jpg: 416x640 14 cars, 112.1ms
# Speed: 3.0ms preprocess, 112.1ms inference, 13.0ms postprocess per image at shape (1, 3, 416, 640)

# %%
# Load YOLO segmentation model
model = YOLO("yolov8n-seg.pt")

# Run inference on an image
image_path = "demo5_images/cars1.jpg"
results = model(image_path)

# Convert results to Supervision format
supervision_detections = sv.Detections.from_ultralytics(results[0])

# Extract masks and class IDs
masks = supervision_detections.mask
class_ids = supervision_detections.class_id

# Load class names (COCO dataset)
class_names = model.names

# Identify the largest mask
largest_area = 0
largest_mask = None

for mask, class_id in zip(masks, class_ids):
    area = np.sum(mask)  # Calculate the area (number of pixels in the mask)
    if area > largest_area:
        largest_area = area
        largest_mask = mask

# Draw the largest mask on the image
if largest_mask is not None:
    # Load the original image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for display

    # Convert mask to a format usable by OpenCV
    largest_mask = (largest_mask * 255).astype(np.uint8)  # Convert to binary mask
    contours, _ = cv2.findContours(largest_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Draw the mask
    cv2.drawContours(image, contours, -1, (255, 0, 0), 2)  # Blue outline
    image[largest_mask > 0] = [255, 0, 0]  # Fill mask with color

    # Display the image
    plt.imshow(image)
    plt.axis("off")
    plt.title("Largest Mask")
    plt.show()
else:
    print("No masks detected!")
# Out:
# image 1/1 d:\8th SEM\Machine Vision\Assignment\Assignment_03\YOLO11\myenv\demo5_images\cars1.jpg: 416x640 14 cars, 189.8ms
# Speed: 2.0ms preprocess, 189.8ms inference, 10.5ms postprocess per image at shape (1, 3, 416, 640)

# %%
# Load the YOLOv8 model
model = YOLO("yolov8n.pt")

# Load the image
image_path = "demo5_images/kingChair.jpg"
image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for display

# Run YOLOv8 inference
results = model(image)

# Loop through detections to calculate centroid for chairs and draw bounding box
for result in results:
    for box in result.boxes:
        class_id = int(box.cls[0])  # Get class ID
        if model.names[class_id] == "chair":  # Only detect chairs (including king chair if classified as "chair")
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates

            # Calculate the centroid of the bounding box
            centroid_x = (x1 + x2) / 2
            centroid_y = (y1 + y2) / 2

            # Draw the bounding box with thicker lines
            cv2.rectangle(image_rgb, (x1, y1), (x2, y2), (255, 0, 0), 2)
            cv2.putText(image_rgb, "King Chair", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2)

            # Draw the centroid of the chair (a green dot)
            cv2.circle(image_rgb, (int(centroid_x), int(centroid_y)), 5, (0, 255, 0), -1)  # Green dot for centroid
            cv2.putText(image_rgb, f"Centroid: ({int(centroid_x)}, {int(centroid_y)})", 
                        (int(centroid_x) + 10, int(centroid_y)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

# Display the output image with bounding box and centroid
plt.figure(figsize=(8, 6))
plt.imshow(image_rgb)
plt.axis("off")
plt.show()
# Out:
# 0: 384x640 1 chair, 86.6ms
# Speed: 3.0ms preprocess, 86.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
! pip install transformers
# Out:
# Collecting transformers
#   Using cached transformers-4.48.3-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: filelock in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from transformers) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2024.11.6-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Using cached tokenizers-0.21.0-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Using cached safetensors-0.5.2-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.27 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2025.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests->transformers) (2025.1.31)
# Using cached transformers-4.48.3-py3-none-any.whl (9.7 MB)
# Downloading regex-2024.11.6-cp312-cp312-win_amd64.whl (273 kB)
# Using cached safetensors-0.5.2-cp38-abi3-win_amd64.whl (303 kB)
# Using cached tokenizers-0.21.0-cp39-abi3-win_amd64.whl (2.4 MB)
# Installing collected packages: safetensors, regex, tokenizers, transformers
# Successfully installed regex-2024.11.6 safetensors-0.5.2 tokenizers-0.21.0 transformers-4.48.3
# WARNING: Ignoring invalid distribution ~umpy (D:\8th SEM\Machine Vision\Assignment\Assignment_03\YOLO11\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\8th SEM\Machine Vision\Assignment\Assignment_03\YOLO11\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\8th SEM\Machine Vision\Assignment\Assignment_03\YOLO11\myenv\Lib\site-packages)

# %%
from transformers import pipeline

# Load Depth Anything V2 model for depth estimation
depth_pipe = pipeline(task="depth-estimation", model="LiheYoung/depth-anything-base-hf")

# Load the image
image_path = "demo5_images/kingChair.jpg"  # Change to your image path
image = Image.open(image_path).convert("RGB")  # Convert to RGB for depth estimation

# Run Depth Anything V2 inference to get the depth map
depth_result = depth_pipe(image)
depth_map = np.array(depth_result["depth"])

# Normalize depth for better visualization
depth_map = (depth_map - depth_map.min()) / (depth_map.max() - depth_map.min())  # Normalize to [0,1]

# Display the depth map
plt.figure(figsize=(8, 6))
plt.imshow(depth_map, cmap="plasma")  # 'plasma' colormap for better contrast
plt.axis("off")
plt.colorbar(label="Depth Value")  # Add colorbar for depth values
plt.title("Depth Map")
plt.show()
# Out:
# Device set to use cpu

# %%
from transformers import pipeline

# Load the YOLOv8 model for chair detection
model = YOLO("yolov8n.pt")

# Load Depth Anything V2 model for depth estimation
depth_pipe = pipeline(task="depth-estimation", model="LiheYoung/depth-anything-base-hf")

# Load the image
image_path = "demo5_images/kingChair.jpg"  # Change to your image path
image = Image.open(image_path).convert("RGB")  # Convert to RGB for depth estimation

# Run YOLOv8 inference to detect chairs and calculate centroid of largest chair
image_bgr = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
results = model(image_rgb)  # Perform detection on the image

# Find the largest chair
largest_chair = None
max_area = 0

for box in results[0].boxes:
    class_id = int(box.cls[0])  # Get the class ID
    if model.names[class_id] == "chair":  # Only consider chair detections
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates
        area = (x2 - x1) * (y2 - y1)  # Area of the bounding box
        if area > max_area:
            max_area = area
            largest_chair = (x1, y1, x2, y2)

# If a largest chair is detected, calculate the centroid
if largest_chair:
    x1, y1, x2, y2 = largest_chair
    centroid_x = (x1 + x2) / 2
    centroid_y = (y1 + y2) / 2

    # Print the centroid coordinates
    print(f"Centroid of the chair: ({centroid_x}, {centroid_y})")

# Run Depth Anything V2 inference to get the depth map
depth_result = depth_pipe(image)
depth_map = np.array(depth_result["depth"])

# Normalize depth for better visualization
depth_map = (depth_map - depth_map.min()) / (depth_map.max() - depth_map.min())  # Normalize to [0,1]

# Query the depth value at the centroid's location (make sure to convert to integer indices)
depth_value = depth_map[int(centroid_y), int(centroid_x)]

# Print the depth value at the centroid
print(f"Depth value at the centroid: {depth_value}")

# Display the depth map
plt.figure(figsize=(8, 6))
plt.imshow(depth_map, cmap="plasma")  # 'plasma' colormap for better contrast
plt.scatter(centroid_x, centroid_y, color="red", label="Centroid", s=100)  # Mark centroid with a red dot
plt.axis("off")
plt.colorbar(label="Depth Value")  # Add colorbar for depth values
plt.title("Depth Map with Centroid")
plt.legend()
plt.show()
# Out:
# Device set to use cpu
# 0: 384x640 1 chair, 110.3ms
# Speed: 29.5ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Centroid of the chair: (352.0, 181.0)
# Depth value at the centroid: 0.6039215686274509

# %%
! pip install gdown
# Out:
# Collecting gdown
# WARNING: Ignoring invalid distribution ~umpy (D:\8th SEM\Machine Vision\Assignment\Assignment_03\YOLO11\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\8th SEM\Machine Vision\Assignment\Assignment_03\YOLO11\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\8th SEM\Machine Vision\Assignment\Assignment_03\YOLO11\myenv\Lib\site-packages)
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from gdown) (4.13.3)
# Requirement already satisfied: filelock in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from gdown) (3.17.0)
# Requirement already satisfied: requests[socks] in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from beautifulsoup4->gdown) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from requests[socks]->gdown) (2025.1.31)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in d:\8th sem\machine vision\assignment\assignment_03\yolo11\myenv\lib\site-packages (from tqdm->gdown) (0.4.6)
# Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Installing collected packages: PySocks, gdown
# Successfully installed PySocks-1.7.1 gdown-5.2.0

# %%
# Downloads the video file from the google drive link, you'll have to "pip install gdown" first
import gdown

file_id = "1zcKvnDDEdyFF4B0B3eYud6DHU19nl0o4"
direct_url = f"https://drive.google.com/uc?id={file_id}"

gdown.download(direct_url, "vehicles_video.mp4", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1zcKvnDDEdyFF4B0B3eYud6DHU19nl0o4
# To: d:\8th SEM\Machine Vision\Assignment\Assignment_03\YOLO11\myenv\vehicles_video.mp4
# 100%|██████████| 35.3M/35.3M [00:14<00:00, 2.49MB/s]
# 'vehicles_video.mp4'

# %%
model = YOLO("yolo11n.pt")
box_annotator = sv.BoxAnnotator()
tracker = sv.ByteTrack()
label_annotator = sv.LabelAnnotator()

def callback(frame: np.ndarray, _: int) -> np.ndarray:
    results = model(frame)[0]
    detections = sv.Detections.from_ultralytics(results)
    detections = tracker.update_with_detections(detections)

    labels = [
        f"#{tracker_id} {results.names[class_id]}"
        for class_id, tracker_id
        in zip(detections.class_id, detections.tracker_id)
    ]

    annotated_frame = box_annotator.annotate(
        frame.copy(), detections=detections)
    return label_annotator.annotate(
        annotated_frame, detections=detections, labels=labels)

sv.process_video(
    source_path="vehicles_video.mp4",
    target_path="result_tracking.mp4",
    callback=callback
)
# Out:
# 0: 384x640 3 cars, 1 truck, 75.1ms
# Speed: 3.9ms preprocess, 75.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 71.0ms
# Speed: 4.0ms preprocess, 71.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 104.2ms
# Speed: 2.0ms preprocess, 104.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 72.8ms
# Speed: 2.0ms preprocess, 72.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 115.6ms
# Speed: 3.0ms preprocess, 115.6ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 107.6ms
# Speed: 4.0ms preprocess, 107.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 80.1ms
# Speed: 2.0ms preprocess, 80.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 132.7ms
# Speed: 8.0ms preprocess, 132.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 73.5ms
# Speed: 5.5ms preprocess, 73.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 80.1ms
# Speed: 3.0ms preprocess, 80.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 77.2ms
# Speed: 2.5ms preprocess, 77.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 64.6ms
# Speed: 3.0ms preprocess, 64.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 69.3ms
# Speed: 39.7ms preprocess, 69.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 59.1ms
# Speed: 2.5ms preprocess, 59.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 59.6ms
# Speed: 3.0ms preprocess, 59.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 63.0ms
# Speed: 2.9ms preprocess, 63.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 68.3ms
# Speed: 2.5ms preprocess, 68.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 70.5ms
# Speed: 2.0ms preprocess, 70.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 60.1ms
# Speed: 3.0ms preprocess, 60.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 58.5ms
# Speed: 3.5ms preprocess, 58.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 79.6ms
# Speed: 4.0ms preprocess, 79.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 64.5ms
# Speed: 3.5ms preprocess, 64.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 88.3ms
# Speed: 24.8ms preprocess, 88.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 65.1ms
# Speed: 3.0ms preprocess, 65.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 59.6ms
# Speed: 3.0ms preprocess, 59.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 60.8ms
# Speed: 3.0ms preprocess, 60.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 58.6ms
# Speed: 3.5ms preprocess, 58.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 63.1ms
# Speed: 4.0ms preprocess, 63.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 62.7ms
# Speed: 2.0ms preprocess, 62.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 73.6ms
# Speed: 2.0ms preprocess, 73.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 61.6ms
# Speed: 4.0ms preprocess, 61.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 65.9ms
# Speed: 2.0ms preprocess, 65.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 67.3ms
# Speed: 3.0ms preprocess, 67.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 56.2ms
# Speed: 3.0ms preprocess, 56.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.6ms
# Speed: 3.0ms preprocess, 56.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 71.1ms
# Speed: 3.0ms preprocess, 71.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 60.1ms
# Speed: 3.0ms preprocess, 60.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 61.8ms
# Speed: 3.0ms preprocess, 61.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.1ms
# Speed: 3.0ms preprocess, 55.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 60.6ms
# Speed: 3.0ms preprocess, 60.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.1ms
# Speed: 2.5ms preprocess, 56.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 60.7ms
# Speed: 2.0ms preprocess, 60.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 57.7ms
# Speed: 2.0ms preprocess, 57.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.5ms
# Speed: 2.5ms preprocess, 55.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.5ms
# Speed: 2.9ms preprocess, 56.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 59.6ms
# Speed: 3.0ms preprocess, 59.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.2ms
# Speed: 3.5ms preprocess, 56.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 59.5ms
# Speed: 2.5ms preprocess, 59.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.5ms
# Speed: 2.5ms preprocess, 57.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 52.5ms
# Speed: 41.0ms preprocess, 52.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.1ms
# Speed: 3.0ms preprocess, 56.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 64.6ms
# Speed: 4.0ms preprocess, 64.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 104.6ms
# Speed: 3.0ms preprocess, 104.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.8ms
# Speed: 3.0ms preprocess, 55.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 60.6ms
# Speed: 2.5ms preprocess, 60.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 64.5ms
# Speed: 3.0ms preprocess, 64.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 58.5ms
# Speed: 2.5ms preprocess, 58.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 61.1ms
# Speed: 3.0ms preprocess, 61.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 65.1ms
# Speed: 2.0ms preprocess, 65.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.6ms
# Speed: 3.0ms preprocess, 57.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 60.5ms
# Speed: 2.5ms preprocess, 60.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 55.1ms
# Speed: 3.0ms preprocess, 55.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 62.1ms
# Speed: 3.0ms preprocess, 62.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 57.6ms
# Speed: 3.0ms preprocess, 57.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 63.5ms
# Speed: 3.5ms preprocess, 63.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 69.1ms
# Speed: 3.0ms preprocess, 69.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 65.5ms
# Speed: 3.0ms preprocess, 65.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 65.6ms
# Speed: 3.0ms preprocess, 65.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 56.0ms
# Speed: 2.5ms preprocess, 56.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 57.5ms
# Speed: 4.0ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 106.6ms
# Speed: 3.0ms preprocess, 106.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 64.0ms
# Speed: 2.5ms preprocess, 64.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 63.5ms
# Speed: 4.0ms preprocess, 63.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.7ms
# Speed: 2.0ms preprocess, 56.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 114.6ms
# Speed: 3.0ms preprocess, 114.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 55.5ms
# Speed: 2.5ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 52.5ms
# Speed: 3.0ms preprocess, 52.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 61.5ms
# Speed: 2.5ms preprocess, 61.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 56.1ms
# Speed: 3.0ms preprocess, 56.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.5ms
# Speed: 3.0ms preprocess, 87.5ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 114.0ms
# Speed: 3.0ms preprocess, 114.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 59.6ms
# Speed: 3.0ms preprocess, 59.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 59.4ms
# Speed: 2.0ms preprocess, 59.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.5ms
# Speed: 2.5ms preprocess, 58.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 61.3ms
# Speed: 3.0ms preprocess, 61.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.2ms
# Speed: 3.0ms preprocess, 57.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 62.1ms
# Speed: 3.0ms preprocess, 62.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 55.7ms
# Speed: 3.0ms preprocess, 55.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 55.7ms
# Speed: 3.0ms preprocess, 55.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 62.1ms
# Speed: 2.5ms preprocess, 62.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 59.1ms
# Speed: 3.0ms preprocess, 59.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.1ms
# Speed: 3.0ms preprocess, 59.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 61.5ms
# Speed: 4.0ms preprocess, 61.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 70.8ms
# Speed: 3.0ms preprocess, 70.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.6ms
# Speed: 3.0ms preprocess, 60.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.1ms
# Speed: 2.5ms preprocess, 62.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 56.1ms
# Speed: 3.0ms preprocess, 56.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.6ms
# Speed: 2.0ms preprocess, 60.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.1ms
# Speed: 3.0ms preprocess, 57.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 64.5ms
# Speed: 3.0ms preprocess, 64.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 67.5ms
# Speed: 3.5ms preprocess, 67.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.0ms
# Speed: 3.0ms preprocess, 54.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.5ms
# Speed: 2.5ms preprocess, 56.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.6ms
# Speed: 3.0ms preprocess, 60.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 94.6ms
# Speed: 2.0ms preprocess, 94.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 60.5ms
# Speed: 3.5ms preprocess, 60.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 67.1ms
# Speed: 2.0ms preprocess, 67.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 70.5ms
# Speed: 3.5ms preprocess, 70.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 69.6ms
# Speed: 4.0ms preprocess, 69.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 63.6ms
# Speed: 3.0ms preprocess, 63.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 4.0ms preprocess, 57.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 68.6ms
# Speed: 4.0ms preprocess, 68.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 72.5ms
# Speed: 3.0ms preprocess, 72.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 53.4ms
# Speed: 2.1ms preprocess, 53.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 71.1ms
# Speed: 3.0ms preprocess, 71.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 68.6ms
# Speed: 3.0ms preprocess, 68.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 64.1ms
# Speed: 2.0ms preprocess, 64.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 75.5ms
# Speed: 4.0ms preprocess, 75.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 74.6ms
# Speed: 3.0ms preprocess, 74.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 62.2ms
# Speed: 4.0ms preprocess, 62.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 68.4ms
# Speed: 3.0ms preprocess, 68.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.6ms
# Speed: 2.9ms preprocess, 57.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.6ms
# Speed: 2.5ms preprocess, 56.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.6ms
# Speed: 3.0ms preprocess, 57.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 68.6ms
# Speed: 44.1ms preprocess, 68.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 61.6ms
# Speed: 3.0ms preprocess, 61.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 59.1ms
# Speed: 3.0ms preprocess, 59.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 69.0ms
# Speed: 3.0ms preprocess, 69.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.6ms
# Speed: 3.0ms preprocess, 57.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 56.6ms
# Speed: 3.0ms preprocess, 56.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 113.7ms
# Speed: 2.0ms preprocess, 113.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.0ms
# Speed: 3.5ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.1ms
# Speed: 3.0ms preprocess, 57.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.1ms
# Speed: 3.0ms preprocess, 56.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 90.5ms
# Speed: 3.0ms preprocess, 90.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 81.5ms
# Speed: 3.5ms preprocess, 81.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 64.6ms
# Speed: 3.0ms preprocess, 64.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 68.0ms
# Speed: 4.0ms preprocess, 68.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 62.6ms
# Speed: 2.9ms preprocess, 62.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 65.8ms
# Speed: 3.0ms preprocess, 65.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 106.6ms
# Speed: 3.0ms preprocess, 106.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.0ms
# Speed: 2.9ms preprocess, 58.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 59.1ms
# Speed: 3.0ms preprocess, 59.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 71.6ms
# Speed: 3.0ms preprocess, 71.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.6ms
# Speed: 3.0ms preprocess, 57.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.5ms
# Speed: 2.5ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 108.6ms
# Speed: 3.0ms preprocess, 108.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.1ms
# Speed: 4.0ms preprocess, 58.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 59.7ms
# Speed: 2.0ms preprocess, 59.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.0ms
# Speed: 61.0ms preprocess, 55.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 62.1ms
# Speed: 2.0ms preprocess, 62.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 57.6ms
# Speed: 3.0ms preprocess, 57.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 68.1ms
# Speed: 3.0ms preprocess, 68.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 60.6ms
# Speed: 2.0ms preprocess, 60.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 109.6ms
# Speed: 2.0ms preprocess, 109.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 57.0ms
# ...
# Speed: 3.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 70.5ms
# Speed: 3.1ms preprocess, 70.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 109.6ms
# Speed: 3.0ms preprocess, 109.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.1ms
# Speed: 4.0ms preprocess, 59.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 56.1ms
# Speed: 3.0ms preprocess, 56.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 63.6ms
# Speed: 4.0ms preprocess, 63.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.9ms
# Speed: 3.0ms preprocess, 60.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.2ms
# Speed: 3.0ms preprocess, 55.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 73.1ms
# Speed: 3.0ms preprocess, 73.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 69.5ms
# Speed: 2.5ms preprocess, 69.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 73.6ms
# Speed: 4.0ms preprocess, 73.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.8ms
# Speed: 3.0ms preprocess, 60.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 66.1ms
# Speed: 3.5ms preprocess, 66.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.0ms
# Speed: 2.5ms preprocess, 62.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.3ms
# Speed: 3.2ms preprocess, 60.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.6ms
# Speed: 3.0ms preprocess, 59.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.1ms
# Speed: 3.0ms preprocess, 61.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 67.1ms
# Speed: 3.0ms preprocess, 67.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 95.6ms
# Speed: 2.6ms preprocess, 95.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 66.5ms
# Speed: 2.0ms preprocess, 66.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 71.5ms
# Speed: 3.0ms preprocess, 71.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 67.0ms
# Speed: 3.0ms preprocess, 67.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 71.6ms
# Speed: 2.0ms preprocess, 71.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 73.2ms
# Speed: 4.0ms preprocess, 73.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 64.1ms
# Speed: 3.0ms preprocess, 64.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.1ms
# Speed: 3.0ms preprocess, 60.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.1ms
# Speed: 3.0ms preprocess, 59.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 69.0ms
# Speed: 2.8ms preprocess, 69.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 64.1ms
# Speed: 3.0ms preprocess, 64.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 66.1ms
# Speed: 4.0ms preprocess, 66.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.1ms
# Speed: 3.0ms preprocess, 62.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 66.5ms
# Speed: 2.5ms preprocess, 66.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.1ms
# Speed: 2.0ms preprocess, 62.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.5ms
# Speed: 2.5ms preprocess, 61.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.0ms
# Speed: 3.1ms preprocess, 57.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.0ms
# Speed: 2.5ms preprocess, 58.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 73.0ms
# Speed: 3.0ms preprocess, 73.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 66.6ms
# Speed: 3.0ms preprocess, 66.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 74.6ms
# Speed: 3.0ms preprocess, 74.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.6ms
# Speed: 3.0ms preprocess, 60.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 65.6ms
# Speed: 3.0ms preprocess, 65.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 125.7ms
# Speed: 3.0ms preprocess, 125.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 62.6ms
# Speed: 3.0ms preprocess, 62.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 57.1ms
# Speed: 2.9ms preprocess, 57.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 65.6ms
# Speed: 3.0ms preprocess, 65.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 69.1ms
# Speed: 3.0ms preprocess, 69.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 68.5ms
# Speed: 3.0ms preprocess, 68.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 67.1ms
# Speed: 2.0ms preprocess, 67.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 66.1ms
# Speed: 3.0ms preprocess, 66.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 75.9ms
# Speed: 3.5ms preprocess, 75.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 69.4ms
# Speed: 3.0ms preprocess, 69.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 71.5ms
# Speed: 2.0ms preprocess, 71.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 60.1ms
# Speed: 3.0ms preprocess, 60.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 57.5ms
# Speed: 1.5ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
model = YOLO("yolo11n.pt")
box_annotator = sv.BoxAnnotator()
tracker = sv.ByteTrack()
label_annotator = sv.LabelAnnotator()

def callback(frame: np.ndarray, _: int) -> np.ndarray:
    results = model(frame)[0]
    detections = sv.Detections.from_ultralytics(results)

    # Filter detections to keep only cars (COCO class ID = 2)
    car_indices = detections.class_id == 2  # Boolean mask
    car_detections = detections[car_indices]  # Apply filter

    # Update tracker only with car detections
    car_detections = tracker.update_with_detections(car_detections)

    labels = [
        f"#{tracker_id} {results.names[class_id]}"
        for class_id, tracker_id
        in zip(car_detections.class_id, car_detections.tracker_id)
    ]

    annotated_frame = box_annotator.annotate(
        frame.copy(), detections=car_detections)
    
    return label_annotator.annotate(
        annotated_frame, detections=car_detections, labels=labels)

sv.process_video(
    source_path="vehicles_video.mp4",
    target_path="car_tracking.mp4",
    callback=callback
)
# Out:
# 0: 384x640 3 cars, 1 truck, 85.6ms
# Speed: 3.0ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 62.5ms
# Speed: 4.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 62.1ms
# Speed: 7.0ms preprocess, 62.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 79.6ms
# Speed: 2.0ms preprocess, 79.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 105.4ms
# Speed: 2.0ms preprocess, 105.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 104.4ms
# Speed: 4.0ms preprocess, 104.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 111.2ms
# Speed: 6.0ms preprocess, 111.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 102.6ms
# Speed: 3.0ms preprocess, 102.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 94.3ms
# Speed: 4.0ms preprocess, 94.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 83.6ms
# Speed: 2.0ms preprocess, 83.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 69.7ms
# Speed: 3.0ms preprocess, 69.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 70.6ms
# Speed: 3.5ms preprocess, 70.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.1ms
# Speed: 3.0ms preprocess, 61.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 100.6ms
# Speed: 4.8ms preprocess, 100.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 64.6ms
# Speed: 3.0ms preprocess, 64.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 65.2ms
# Speed: 3.0ms preprocess, 65.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 74.6ms
# Speed: 3.0ms preprocess, 74.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 71.0ms
# Speed: 3.0ms preprocess, 71.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 80.6ms
# Speed: 4.0ms preprocess, 80.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 63.6ms
# Speed: 2.9ms preprocess, 63.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 78.1ms
# Speed: 4.0ms preprocess, 78.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 59.1ms
# Speed: 3.0ms preprocess, 59.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 54.5ms
# Speed: 2.5ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 54.1ms
# Speed: 3.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 68.1ms
# Speed: 4.0ms preprocess, 68.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 101.6ms
# Speed: 4.0ms preprocess, 101.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 80.1ms
# Speed: 2.0ms preprocess, 80.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 84.6ms
# Speed: 5.0ms preprocess, 84.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 92.2ms
# Speed: 3.0ms preprocess, 92.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 99.6ms
# Speed: 4.0ms preprocess, 99.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 72.6ms
# Speed: 3.0ms preprocess, 72.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 60.5ms
# Speed: 4.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 85.6ms
# Speed: 3.7ms preprocess, 85.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 65.7ms
# Speed: 3.0ms preprocess, 65.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 66.6ms
# Speed: 3.0ms preprocess, 66.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 66.6ms
# Speed: 3.0ms preprocess, 66.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 68.5ms
# Speed: 3.0ms preprocess, 68.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 65.6ms
# Speed: 3.0ms preprocess, 65.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 72.1ms
# Speed: 3.5ms preprocess, 72.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 68.1ms
# Speed: 3.0ms preprocess, 68.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 80.6ms
# Speed: 2.0ms preprocess, 80.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 68.5ms
# Speed: 2.5ms preprocess, 68.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 65.5ms
# Speed: 3.0ms preprocess, 65.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 61.1ms
# Speed: 3.0ms preprocess, 61.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 78.6ms
# Speed: 5.0ms preprocess, 78.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 81.8ms
# Speed: 44.8ms preprocess, 81.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 73.1ms
# Speed: 3.0ms preprocess, 73.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 64.1ms
# Speed: 2.0ms preprocess, 64.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 69.6ms
# Speed: 3.0ms preprocess, 69.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 72.5ms
# Speed: 3.0ms preprocess, 72.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 69.0ms
# Speed: 3.0ms preprocess, 69.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 68.1ms
# Speed: 3.0ms preprocess, 68.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 75.1ms
# Speed: 2.0ms preprocess, 75.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 78.6ms
# Speed: 3.0ms preprocess, 78.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 69.0ms
# Speed: 4.0ms preprocess, 69.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 63.5ms
# Speed: 4.0ms preprocess, 63.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 67.1ms
# Speed: 2.0ms preprocess, 67.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 60.1ms
# Speed: 3.0ms preprocess, 60.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 74.0ms
# Speed: 4.0ms preprocess, 74.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 72.2ms
# Speed: 3.0ms preprocess, 72.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 62.1ms
# Speed: 3.5ms preprocess, 62.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 61.7ms
# Speed: 3.0ms preprocess, 61.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 71.6ms
# Speed: 2.0ms preprocess, 71.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 62.6ms
# Speed: 4.0ms preprocess, 62.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 102.6ms
# Speed: 2.5ms preprocess, 102.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 63.0ms
# Speed: 2.5ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 59.6ms
# Speed: 3.0ms preprocess, 59.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 76.7ms
# Speed: 4.0ms preprocess, 76.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 75.6ms
# Speed: 3.0ms preprocess, 75.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 72.0ms
# Speed: 4.0ms preprocess, 72.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 54.1ms
# Speed: 3.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 59.1ms
# Speed: 3.0ms preprocess, 59.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 71.1ms
# Speed: 2.0ms preprocess, 71.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.5ms
# Speed: 2.5ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 71.6ms
# Speed: 2.6ms preprocess, 71.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 106.6ms
# Speed: 3.0ms preprocess, 106.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 66.1ms
# Speed: 2.0ms preprocess, 66.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.6ms
# Speed: 3.0ms preprocess, 57.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 54.6ms
# Speed: 3.0ms preprocess, 54.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.1ms
# Speed: 3.0ms preprocess, 57.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 62.1ms
# Speed: 2.0ms preprocess, 62.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 58.6ms
# Speed: 3.0ms preprocess, 58.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 55.1ms
# Speed: 4.0ms preprocess, 55.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 106.6ms
# Speed: 2.0ms preprocess, 106.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 59.1ms
# Speed: 2.5ms preprocess, 59.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 58.5ms
# Speed: 2.5ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 60.1ms
# Speed: 3.0ms preprocess, 60.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.5ms
# Speed: 2.5ms preprocess, 58.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 61.0ms
# Speed: 2.5ms preprocess, 61.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 57.1ms
# Speed: 3.0ms preprocess, 57.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 76.5ms
# Speed: 2.0ms preprocess, 76.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 51.5ms
# Speed: 3.0ms preprocess, 51.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 56.1ms
# Speed: 3.0ms preprocess, 56.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 61.1ms
# Speed: 2.5ms preprocess, 61.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 56.6ms
# Speed: 3.0ms preprocess, 56.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 66.0ms
# Speed: 3.0ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 52.1ms
# Speed: 3.0ms preprocess, 52.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 65.5ms
# Speed: 3.0ms preprocess, 65.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 52.5ms
# Speed: 3.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 51.1ms
# Speed: 3.0ms preprocess, 51.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 58.6ms
# Speed: 3.0ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.0ms
# Speed: 2.5ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.5ms
# Speed: 3.5ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.1ms
# Speed: 3.0ms preprocess, 55.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 102.0ms
# Speed: 3.0ms preprocess, 102.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 55.6ms
# Speed: 3.0ms preprocess, 55.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 70.6ms
# Speed: 3.0ms preprocess, 70.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 54.1ms
# Speed: 2.5ms preprocess, 54.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 56.3ms
# Speed: 3.0ms preprocess, 56.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 82.6ms
# Speed: 2.0ms preprocess, 82.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 69.5ms
# Speed: 2.5ms preprocess, 69.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 54.1ms
# Speed: 2.5ms preprocess, 54.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 58.5ms
# Speed: 4.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 56.4ms
# Speed: 3.0ms preprocess, 56.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 107.6ms
# Speed: 3.0ms preprocess, 107.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 82.3ms
# Speed: 3.0ms preprocess, 82.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 108.6ms
# Speed: 3.0ms preprocess, 108.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 102.6ms
# Speed: 3.5ms preprocess, 102.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 117.6ms
# Speed: 4.0ms preprocess, 117.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 86.6ms
# Speed: 3.0ms preprocess, 86.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 81.6ms
# Speed: 3.0ms preprocess, 81.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 158.3ms
# Speed: 2.0ms preprocess, 158.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 112.1ms
# Speed: 3.0ms preprocess, 112.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 102.6ms
# Speed: 6.0ms preprocess, 102.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 111.7ms
# Speed: 4.8ms preprocess, 111.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 96.4ms
# Speed: 5.0ms preprocess, 96.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 106.1ms
# Speed: 3.0ms preprocess, 106.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 66.6ms
# Speed: 2.0ms preprocess, 66.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 66.0ms
# Speed: 3.0ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 66.0ms
# Speed: 4.0ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 64.6ms
# Speed: 3.0ms preprocess, 64.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 55.6ms
# Speed: 2.7ms preprocess, 55.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 76.0ms
# Speed: 3.0ms preprocess, 76.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 71.5ms
# Speed: 3.0ms preprocess, 71.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.8ms
# Speed: 3.0ms preprocess, 58.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.1ms
# Speed: 3.0ms preprocess, 57.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 70.6ms
# Speed: 4.0ms preprocess, 70.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.0ms
# Speed: 2.5ms preprocess, 56.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 55.5ms
# Speed: 2.5ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 48.5ms
# Speed: 2.0ms preprocess, 48.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.8ms
# Speed: 3.0ms preprocess, 54.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 72.1ms
# Speed: 2.0ms preprocess, 72.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 65.6ms
# Speed: 3.0ms preprocess, 65.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 63.0ms
# Speed: 3.5ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 69.4ms
# Speed: 3.0ms preprocess, 69.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.0ms
# Speed: 3.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 59.1ms
# Speed: 3.0ms preprocess, 59.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.0ms
# Speed: 2.5ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 59.1ms
# Speed: 3.0ms preprocess, 59.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.5ms
# Speed: 2.9ms preprocess, 57.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.0ms
# Speed: 3.5ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.2ms
# Speed: 3.0ms preprocess, 56.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 60.1ms
# Speed: 3.0ms preprocess, 60.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 110.1ms
# Speed: 3.0ms preprocess, 110.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 60.1ms
# Speed: 3.5ms preprocess, 60.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 54.0ms
# Speed: 4.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 56.6ms
# Speed: 2.9ms preprocess, 56.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.6ms
# Speed: 2.0ms preprocess, 50.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 79.6ms
# Speed: 9.0ms preprocess, 79.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 52.6ms
# Speed: 3.0ms preprocess, 52.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 56.1ms
# Speed: 3.0ms preprocess, 56.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 51.5ms
# Speed: 3.0ms preprocess, 51.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 56.5ms
# Speed: 2.5ms preprocess, 56.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 101.6ms
# Speed: 2.0ms preprocess, 101.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.1ms
# Speed: 3.0ms preprocess, 55.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 52.1ms
# Speed: 2.0ms preprocess, 52.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.1ms
# Speed: 3.0ms preprocess, 54.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 77.1ms
# Speed: 2.5ms preprocess, 77.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.6ms
# Speed: 1.0ms preprocess, 55.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 102.6ms
# Speed: 3.0ms preprocess, 102.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 54.5ms
# Speed: 2.5ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 63.6ms
# Speed: 3.0ms preprocess, 63.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.0ms
# Speed: 3.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 51.6ms
# Speed: 1.9ms preprocess, 51.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.6ms
# Speed: 2.5ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.0ms
# Speed: 3.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 55.1ms
# Speed: 3.0ms preprocess, 55.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 63.2ms
# Speed: 42.0ms preprocess, 63.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 53.5ms
# Speed: 2.5ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.0ms
# Speed: 3.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.5ms
# Speed: 2.5ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 52.5ms
# Speed: 2.5ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 66.0ms
# Speed: 3.0ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 65.1ms
# Speed: 3.0ms preprocess, 65.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.1ms
# Speed: 3.0ms preprocess, 54.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.6ms
# Speed: 3.0ms preprocess, 58.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.1ms
# Speed: 3.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.6ms
# Speed: 3.0ms preprocess, 53.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 106.6ms
# Speed: 3.0ms preprocess, 106.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 52.5ms
# Speed: 3.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.6ms
# Speed: 2.0ms preprocess, 53.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 51.0ms
# Speed: 3.0ms preprocess, 51.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 74.6ms
# Speed: 3.0ms preprocess, 74.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 57.0ms
# Speed: 3.5ms preprocess, 57.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 53.7ms
# Speed: 2.0ms preprocess, 53.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 51.1ms
# Speed: 3.0ms preprocess, 51.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 100.0ms
# ...
# Speed: 2.0ms preprocess, 63.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 52.1ms
# Speed: 2.0ms preprocess, 52.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.6ms
# Speed: 4.5ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.1ms
# Speed: 2.5ms preprocess, 55.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 53.1ms
# Speed: 3.0ms preprocess, 53.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 103.5ms
# Speed: 2.5ms preprocess, 103.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 56.5ms
# Speed: 2.5ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.1ms
# Speed: 3.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.1ms
# Speed: 3.0ms preprocess, 61.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.1ms
# Speed: 3.0ms preprocess, 60.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 74.5ms
# Speed: 6.0ms preprocess, 74.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.0ms
# Speed: 3.5ms preprocess, 60.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 65.6ms
# Speed: 3.0ms preprocess, 65.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.6ms
# Speed: 2.5ms preprocess, 60.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 53.5ms
# Speed: 2.5ms preprocess, 53.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.5ms
# Speed: 1.8ms preprocess, 54.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 64.1ms
# Speed: 2.0ms preprocess, 64.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 52.1ms
# Speed: 2.5ms preprocess, 52.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.0ms
# Speed: 4.0ms preprocess, 58.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.1ms
# Speed: 4.0ms preprocess, 57.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.5ms
# Speed: 2.7ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 53.1ms
# Speed: 2.8ms preprocess, 53.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 53.5ms
# Speed: 2.9ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.1ms
# Speed: 39.3ms preprocess, 62.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.1ms
# Speed: 3.0ms preprocess, 54.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 62.1ms
# Speed: 3.0ms preprocess, 62.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.4ms
# Speed: 3.2ms preprocess, 59.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.6ms
# Speed: 3.0ms preprocess, 54.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 54.1ms
# Speed: 3.0ms preprocess, 54.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 52.5ms
# Speed: 3.5ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 58.9ms
# Speed: 2.0ms preprocess, 58.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 56.1ms
# Speed: 3.0ms preprocess, 56.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 81.5ms
# Speed: 4.1ms preprocess, 81.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 66.1ms
# Speed: 3.0ms preprocess, 66.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 53.6ms
# Speed: 3.0ms preprocess, 53.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 60.5ms
# Speed: 3.5ms preprocess, 60.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 63.8ms
# Speed: 3.0ms preprocess, 63.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 58.6ms
# Speed: 3.0ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 75.6ms
# Speed: 49.5ms preprocess, 75.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 63.6ms
# Speed: 2.6ms preprocess, 63.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 55.0ms
# Speed: 3.5ms preprocess, 55.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 52.1ms
# Speed: 2.0ms preprocess, 52.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 98.6ms
# Speed: 2.5ms preprocess, 98.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 52.1ms
# Speed: 2.0ms preprocess, 52.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
import os
import gdown

VIDEO_PATH = "vehicles_video.mp4"

def process_video():
    # Initialize YOLO model
    model = YOLO("yolo11n.pt")
    
    # Initialize tracker
    tracker = sv.ByteTrack()
    
    # Create annotators
    box_annotator = sv.BoxAnnotator(thickness=2, color=sv.Color.RED)
    trace_annotator = sv.TraceAnnotator(color=sv.Color.GREEN, thickness=2)  # Track traces in green
    
    # Open video capture
    cap = cv2.VideoCapture(VIDEO_PATH)
    if not cap.isOpened():
        print("Error: Could not open video file")
        return
    
    # Get video properties
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    
    # Initialize video writer
    output_path = "output_video_with_traces.mp4"
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    
    # Set display window size
    display_scale = 0.3
    display_width = int(width * display_scale)
    display_height = int(height * display_scale)
    
    print("Processing video... Press 'q' to quit")
    
    frame_count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
            
        try:
            # Detect objects in the frame
            results = model(frame, verbose=False)[0]
            
            # Ensure results contain valid detections
            if not results or results.boxes is None or len(results.boxes) == 0:
                out.write(frame)  # Write original frame if no detections
                continue

            # Convert detections to supervision format
            detections = sv.Detections.from_ultralytics(results)

            # Ensure detections are valid before proceeding
            if detections is None or len(detections) == 0:
                out.write(frame)  # Write original frame if no valid detections
                continue
            
            # Filter for cars only (class_id 2 in COCO dataset)
            car_indices = [i for i, class_id in enumerate(detections.class_id) if class_id == 2]
            
            if not car_indices:
                out.write(frame)  # No cars detected, write original frame
                continue
            
            detections = detections[car_indices]  # Keep only car detections

            # Track detections
            detections = tracker.update_with_detections(detections)
                
            # Draw tracking traces
            frame = trace_annotator.annotate(scene=frame, detections=detections)
                
            # Draw bounding boxes with tracker ID
            frame = box_annotator.annotate(scene=frame, detections=detections)
                
            # Add tracker ID labels with white background for visibility
            for xyxy, tracker_id in zip(detections.xyxy, detections.tracker_id):
                if tracker_id is None:
                    continue  # Skip if tracker ID is missing
                
                # Convert coordinates to integers
                x1, y1, x2, y2 = map(int, xyxy)
                
                # Create label with tracker ID
                label = f"Car {int(tracker_id)}"
                
                # Get label size for background
                (label_width, label_height), _ = cv2.getTextSize(
                    label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2
                )
                
                # Draw white background for label
                cv2.rectangle(
                    frame,
                    (x1, y1 - label_height - 10),
                    (x1 + label_width, y1),
                    (255, 255, 255),
                    -1
                )
                
                # Draw label text
                cv2.putText(
                    frame,
                    label,
                    (x1, y1 - 5),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.5,
                    (0, 0, 0),  # Black text
                    2
                )
        
        except Exception as e:
            print(f"Error processing frame {frame_count}: {str(e)}")
        
        # Write the frame to output video
        out.write(frame)
        
        # Resize the frame for display
        resized_frame = cv2.resize(frame, (display_width, display_height))
        
        # Display the frame
        cv2.imshow('Car Tracking with Traces', resized_frame)
        
        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
            
        frame_count += 1
    
    # Release everything
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    
    print(f"Video processing completed! Output saved as {output_path}")

if __name__ == "__main__":
    process_video()
# Out:
# Processing video... Press 'q' to quit
# Video processing completed! Output saved as output_video_with_traces.mp4

# %% [markdown]
# The function definition `def callback(frame: np.ndarray, _: int) -> np.ndarray:` is commonly used in the context of machine vision and video processing, especially when working with pre-trained neural networks for tasks like object detection, tracking, or video frame processing. Let’s break it down:
#
# 1. "callback": This is the name of the function. It’s a conventionally used term for a function that is passed as an argument to another function and is invoked at a later time.
#
# 2. "frame: np.ndarray": This represents the first parameter of the function, `frame`, which is expected to be a NumPy array. In video or image processing, a frame is typically a 2D or 3D array that represents pixel values of a single image or a video frame. The `np.ndarray` type hint suggests that this parameter will be a NumPy array, which is a popular library for handling arrays efficiently in Python.
#
# 3. "_: int": The underscore (`_`) here is a common Python convention for an unused variable. This means that the second parameter, which is expected to be an integer (likely a frame counter or index in the context of video processing), will be passed to the function but will not be used in the function body. This can be useful if you need to comply with a function signature but don't actually need to use the parameter.
#
# 4. "-> np.ndarray": This part of the definition specifies that the function will return a value of type `np.ndarray`, meaning the function is expected to return a NumPy array. In this context, this could represent the processed version of the frame, such as an image with detected objects, or it could be a modified frame after some analysis or transformation.
